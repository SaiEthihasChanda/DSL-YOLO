# %%
# !pip install Flask
# Out:
# Requirement already satisfied: Flask in c:\users\saiet\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\saiet\anaconda3\lib\site-packages (from Flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\saiet\anaconda3\lib\site-packages (from Flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\saiet\anaconda3\lib\site-packages (from Flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\saiet\anaconda3\lib\site-packages (from Flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\saiet\anaconda3\lib\site-packages (from Flask) (1.6.2)
# Requirement already satisfied: colorama in c:\users\saiet\anaconda3\lib\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\saiet\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask) (2.1.3)

# %%
import requests
import pandas as pd

# Path to the image you want to upload
image_path = 'svmtest/patches_199.jpg'  # Change this to your test image

# Endpoint URL
url = 'http://127.0.0.1:5000/upload'

# Send POST request with image
with open(image_path, 'rb') as img_file:
    files = {'image': img_file}
    response = requests.post(url, files=files)

# Check if the request was successful
if response.status_code == 200:
    print("Request successful!")
    with open('hdfovfhifhvipedjfvgpigjb.png', 'wb') as f:
        f.write(response.content)

    # Parse the JSON response
    
    
    # Check if the response contains the 'features' key
    
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# Request successful!

# %%
df
# Out:
#           0         1        10       100       101       102       103  \
# 0 -0.100034  0.132286 -0.050439  0.241525  0.029774  0.113396  0.036597
#
#         104      105       106  ...  Diss_sim2  Diss_sim3    Energy   Energy2  \
# 0  0.005103  0.03147  0.396675  ...  16.405738  19.007172  0.064512  0.051802
#
#     Energy3   Energy4  Homogen  Homogen2  svm_pred  svm_pred_label
# 0  0.055838  0.188703  0.25578  0.142567         5       scratches
#
# [1 rows x 273 columns]
